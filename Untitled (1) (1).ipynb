# %%
import pandas as pd
import tensorflow as tf
import numpy as np

# %%
datakerala = pd.read_csv('/content/kerala.csv')

# %%
datakerala.head()
# Out:
#   SUBDIVISION  YEAR   JAN   FEB   MAR    APR    MAY     JUN     JUL    AUG  \
# 0      KERALA  1901  28.7  44.7  51.6  160.0  174.7   824.6   743.0  357.5
# 1      KERALA  1902   6.7   2.6  57.3   83.9  134.5   390.9  1205.0  315.8
# 2      KERALA  1903   3.2  18.6   3.1   83.6  249.7   558.6  1022.5  420.2
# 3      KERALA  1904  23.7   3.0  32.2   71.5  235.7  1098.2   725.5  351.8
# 4      KERALA  1905   1.2  22.3   9.4  105.9  263.3   850.2   520.5  293.6
#
#      SEP    OCT    NOV    DEC   ANNUAL RAINFALL FLOODS
# 0  197.7  266.9  350.8   48.4            3248.6    YES
# 1  491.6  358.4  158.3  121.5            3326.6    YES
# 2  341.8  354.1  157.0   59.0            3271.2    YES
# 3  222.7  328.1   33.9    3.3            3129.7    YES
# 4  217.2  383.5   74.4    0.2            2741.6     NO

# %%
datakerala.isnull().sum()
# Out:
# SUBDIVISION         0
# YEAR                0
# JAN                 0
# FEB                 0
# MAR                 0
# APR                 0
# MAY                 0
# JUN                 0
# JUL                 0
# AUG                 0
# SEP                 0
# OCT                 0
# NOV                 0
# DEC                 0
#  ANNUAL RAINFALL    0
# FLOODS              0
# dtype: int64

# %%
 # For jan 
data = datakerala[['JAN']].values


test_size = 0.2

dataset_train = data[:int(len(data)*(1 - test_size)),:]
dataset_test =  data[int(len(data)*(1 - test_size)):,:]

from sklearn.preprocessing import MinMaxScaler
sc = MinMaxScaler(feature_range = (0, 1))
training_set_scaled = sc.fit_transform(dataset_train)   # used because of error percentage
test_set_scaled = sc.transform(dataset_test)


print(training_set_scaled.shape)
X_train = []
Y_train = []

LEN = 20
for i  in  range(LEN,len(training_set_scaled)):
  X_train.append(training_set_scaled[i-LEN:i,0])
  Y_train.append(training_set_scaled[i,0])

X_test = []
Y_test = []


for i  in  range(LEN,len(test_set_scaled)):
  X_test.append(test_set_scaled[i-LEN:i,0])
  Y_test.append(test_set_scaled[i,0])


X_train, Y_train = np.array(X_train), np.array(Y_train) 
X_train = np.reshape(X_train, (X_train.shape[0], X_train.shape[1], 1))

X_test, Y_test = np.array(X_test), np.array(Y_test) 
X_test = np.reshape(X_test, (X_test.shape[0], X_test.shape[1], 1))

#Y_train = Y_train.reshape(-1,1)
print(f"{Y_train.shape} , {X_train.shape}")
print(f"{Y_test.shape} , {X_test.shape}")

from keras.models import Sequential
from keras.layers import Dense
from keras.layers import LSTM
from keras.layers import Dropout # it drops some certain percentage of connection in between two layers.


model = Sequential()

model.add(LSTM(units = 50, return_sequences = True, input_shape = (X_train.shape[1], 1)))
model.add(Dropout(0.2))



model.add(LSTM(units = 50, return_sequences = True))
model.add(Dropout(0.2))
model.add(LSTM(units = 50, return_sequences = True))
model.add(Dropout(0.2))
model.add(LSTM(units = 50, return_sequences = True))
model.add(Dropout(0.2))
model.add(LSTM(units = 50, return_sequences = True))
model.add(Dropout(0.2))

model.add(LSTM(units = 50))
model.add(Dropout(0.2))


model.add(Dense(units = 1))

model.compile(optimizer = 'adam', loss = 'mean_squared_error')

##
# Out:
# (94, 1)
# (74,) , (74, 20, 1)
# (4,) , (4, 20, 1)

# %%
model.fit(X_train, Y_train, epochs = 4000, batch_size = 32)
# Out:
# Streaming output truncated to the last 5000 lines.
# 3/3 [==============================] - 0s 18ms/step - loss: 0.0315
# Epoch 1502/4000
# 3/3 [==============================] - 0s 19ms/step - loss: 0.0325
# Epoch 1503/4000
# 3/3 [==============================] - 0s 19ms/step - loss: 0.0355
# Epoch 1504/4000
# 3/3 [==============================] - 0s 19ms/step - loss: 0.0321
# Epoch 1505/4000
# 3/3 [==============================] - 0s 19ms/step - loss: 0.0306
# Epoch 1506/4000
# 3/3 [==============================] - 0s 19ms/step - loss: 0.0338
# Epoch 1507/4000
# 3/3 [==============================] - 0s 23ms/step - loss: 0.0353
# Epoch 1508/4000
# 3/3 [==============================] - 0s 22ms/step - loss: 0.0359
# Epoch 1509/4000
# 3/3 [==============================] - 0s 19ms/step - loss: 0.0335
# Epoch 1510/4000
# 3/3 [==============================] - 0s 19ms/step - loss: 0.0406
# Epoch 1511/4000
# 3/3 [==============================] - 0s 22ms/step - loss: 0.0357
# ...

# %%
Y_pred = model.predict(X_train)
Y_pred_test = model.predict(X_test)
# Out:
# ...
# 1/1 [==============================] - 0s 28ms/step

# %%
import matplotlib.pyplot as plt
plt.plot(Y_train,color = "blue" , label = "real")
plt.plot(Y_pred,color = "red" , label = "predicted")

plt.legend()

plt.show()

# %%
import matplotlib.pyplot as plt
plt.plot(Y_train,color = "blue" , label = "real")
plt.plot(Y_pred,color = "red" , label = "predicted")

plt.legend()

plt.show()

# %%
import matplotlib.pyplot as plt
plt.plot(Y_test,color = "blue" , label = "real")
plt.plot(Y_pred_test,color = "red" , label = "predicted")

plt.legend()

plt.show()
